# %% [markdown]
# <a href="https://colab.research.google.com/github/survhi/ssis/blob/main/pyspark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
pip install pyspark

# %%
import pyspark

# %%
import pandas as pd

# %%
pd.read_csv("/content/sample_data/california_housing_test.csv")
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
from pyspark.sql import SparkSession

# %%
spark= SparkSession.builder.appName('dataframe').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://8296cc89d7b5:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>dataframe</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
## read the dataset with show
##df_pyspark= spark.read.option('header','true').csv('/content/test.csv').show()
## read data without show() to check the schema
df_pyspark = spark.read.option('header','true').csv('/content/test.csv', inferSchema=True)

# %%
## read schema IF IN above line inferschema=true is not there then all datatype will string
df_pyspark.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- experience: integer (nullable = true)

# %%
#another way to read file
df_pyspark= spark.read.csv('/content/test.csv', header=True,inferSchema=True)
df_pyspark.show()
# Out:
# +------+---+----------+
# |  name|age|experience|
# +------+---+----------+
# | sunny| 20|         3|
# |vivvan| 69|        30|
# |  aman| 69|        32|
# |  ajay| 56|        26|
# |  ajit| 43|        19|
# |  asar| 75|        45|
# +------+---+----------+

# %%
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.columns
# Out:
# ['name', 'age', 'experience']

# %%
#in pandas we get head in dataframe formate here we will get in list format
df_pyspark.head(2)
# Out:
# [Row(name='sunny', age=20, experience=3),
#  Row(name='vivvan', age=69, experience=30)]
